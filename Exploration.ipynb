# %% [markdown]
# ### Exploring Etsy APIs

# %% [markdown]
# [Available APIs](https://www.etsy.com/developers/documentation/getting_started/api_basics)

# %%
import requests
import json
# !pip install pandas
import pandas as pd
# !pip install jsontable
import jsontable
import io
import time
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 50.0 MB/s
# ...
